# %%
import os

training_data = os.listdir("train/")

print(training_data)

# %%
lables = []

for i in training_data:
    if "cat" in i:
        lables.append(0)
    else:
        lables.append(1)

print(lables)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

cat_image = img.imread("train/cat.0.jpg")
plt.imshow(cat_image)

# %%
dog_image = img.imread("train/dog.10005.jpg")
plt.imshow(dog_image)
